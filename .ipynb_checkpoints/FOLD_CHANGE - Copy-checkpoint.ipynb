# %% [markdown]
# # 1. Importing all necessary libs and modules

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Reading and filtered data

# %%
# The Normal and Cancerous Samples
df_cancer = pd.read_csv("filtered/cancer.csv", sep=",")
df_healthy= pd.read_csv("filtered/normal.csv", sep=",")

# The Results of hypothesis testing on the paired data 
paired= pd.read_csv("filtered/paired_fdr_2sided.csv",sep=",")
paired
# Out:
#        Unnamed: 0    Hugo_Symbol  Entrez_Gene_Id normality             p  \
# 0               0       HIST3H2A           92815       NOT  1.008929e-08
# 1               1          LIN7B           64130    NORMAL  2.384960e-01
# 2               2            LXN           56925       NOT  1.725267e-06
# 3               3         CNKSR2           22866    NORMAL  1.265880e-08
# 4               4          SCML1            6322    NORMAL  1.601853e-02
# ...           ...            ...             ...       ...           ...
# 17270       17270         ZNF521           25925       NaN  8.775508e-06
# 17271       17271         SPINT2           10653       NaN  4.778330e-09
# 17272       17272         HAVCR2           84868       NaN  3.366814e-09
# 17273       17273  CTD-2116N17.1               0       NaN  2.964334e-09
# 17274       17274           FUT2            2524       NaN  5.339358e-08
#
#         stat  expressed  fdr_hypothesis           fdr  corrected
# 0       44.0       True            True  4.682766e-08      False
# 1      494.0      False           False  2.756234e-01      False
# 2      142.0       True            True  4.290195e-06      False
# 3       48.0       True            True  5.630297e-08      False
# 4      388.0       True            True  2.223009e-02      False
# ...      ...        ...             ...           ...        ...
# 17270  177.0       True            True  1.934868e-05      False
# 17271   31.0       True            True  2.616344e-08      False
# 17272   25.0       True            True  2.030077e-08      False
# 17273   16.0       True            True  1.858329e-08      False
# 17274   74.0       True            True  1.873602e-07      False
#
# [17275 rows x 10 columns]

# %%
df_cancer
# Out:
#        Unnamed: 0    Hugo_Symbol  Entrez_Gene_Id  TCGA-43-7657  TCGA-58-8386  \
# 0               0       HIST3H2A           92815        336.79        500.46
# 1               1          LIN7B           64130        105.15        212.78
# 2               2            LXN           56925        848.22        236.21
# 3               3         CNKSR2           22866         32.59          8.51
# 4               4          SCML1            6322         84.63         74.58
# ...           ...            ...             ...           ...           ...
# 17270       19641         ZNF521           25925         37.32         76.71
# 17271       19642         SPINT2           10653      56265.94       3901.01
# 17272       19643         HAVCR2           84868         74.58        432.53
# 17273       19646  CTD-2116N17.1               0          6.89         10.79
# 17274       19647           FUT2            2524        105.15         58.30
#
#        TCGA-22-5478  TCGA-22-5472  TCGA-43-5670  TCGA-60-2709  TCGA-22-5489  \
# 0            703.28        287.01        486.75         70.51        145.02
# 1            102.25        212.78        172.65        244.57        105.89
# 2            271.48        759.08         61.25        620.67        329.84
# 3             45.85          6.16         49.21         11.91         12.27
# 4             67.12         57.89        102.97        132.44         66.65
# ...             ...           ...           ...           ...           ...
# 17270         59.97         84.04         14.24        202.66        435.55
# 17271      16843.62      12244.81      37901.36       8479.89       9606.86
# 17272        128.79        208.38         13.93        633.73        348.71
# 17273          8.51          6.84          9.13          9.93         14.78
# 17274         39.79       1059.11        366.09         97.36         46.50
#
#        ...  TCGA-85-7710  TCGA-56-7580  TCGA-43-6647  TCGA-90-6837  \
# 0      ...          3.06        420.68        109.66        106.63
# 1      ...        135.24        135.24        151.22        395.18
# 2      ...        688.78        204.07        438.59        503.95
# 3      ...          1.38          6.62          6.11          1.66
# 4      ...        165.57        119.26         87.65         53.57
# ...    ...           ...           ...           ...           ...
# 17270  ...         22.59         33.78        148.09        106.63
# 17271  ...      18052.61      15392.14      20030.74      20593.91
# 17272  ...        150.17         57.49        236.21        353.59
# 17273  ...          8.85          6.21          4.94         17.64
# 17274  ...        106.63         35.50         55.49        738.29
#
#        TCGA-56-8083  TCGA-51-4079  TCGA-56-7222  TCGA-22-4593  TCGA-51-4081  \
# 0           1233.75        172.65        303.44        228.13        251.48
# 1            295.11        120.94        114.36         96.68        277.20
# 2           3039.30        607.87        106.63        507.46        255.00
# 3             33.54          3.11          0.82          3.32         27.25
# 4            232.94         67.12         64.80         90.14        198.47
# ...             ...           ...           ...           ...           ...
# 17270        297.17         22.26         25.72        106.63         71.00
# 17271       9808.75      11189.60      10733.74      10014.87       6983.79
# 17272         29.48        202.66         33.78         73.54         55.89
# 17273         28.65         14.78         27.64         15.80         31.00
# 17274        232.94        244.57         71.50         53.57        332.14
#
#        TCGA-56-8309
# 0             23.59
# 1            153.34
# 2            346.29
# 3              6.16
# 4            154.42
# ...             ...
# 17270         37.05
# 17271      23169.48
# 17272        480.04
# 17273          4.86
# 17274         69.52
#
# [17275 rows x 53 columns]

# %%
df_healthy.iloc[:,3:]
# Out:
#        TCGA-43-7657  TCGA-58-8386  TCGA-22-5478  TCGA-22-5472  TCGA-43-5670  \
# 0             62.12        130.60         33.06         35.50         73.03
# 1            185.11        283.05        119.26        169.07        165.57
# 2            909.17        819.30        412.00        743.43       1340.84
# 3             41.81         18.29         40.93         67.12         54.72
# 4            133.36        214.27        108.14        109.66        190.34
# ...             ...           ...           ...           ...           ...
# 17270        215.77        148.09         83.45        232.94        167.90
# 17271       6792.79       5441.30       5831.91       5329.30       5711.87
# 17272        423.61        529.06        660.68        620.67        518.15
# 17273          0.00          0.00          0.99          3.59          2.23
# 17274         64.34        101.54         14.45         69.52        110.43
#
#        TCGA-60-2709  TCGA-22-5489  TCGA-77-8007  TCGA-22-5471  TCGA-22-4609  \
# 0             60.39         92.05         66.65         54.33         15.56
# 1            161.02        131.51        198.47        175.07        147.06
# 2            607.87       1709.26       1709.26        603.67        555.41
# 3             29.27         20.26         23.76         28.04         39.22
# 4            211.31         96.01        208.38        120.10        239.52
# ...             ...           ...           ...           ...           ...
# 17270         80.01        161.02        104.42         81.14        113.56
# 17271       6164.49       8134.41       6516.03       8598.28       5633.22
# 17272        848.22        366.09       1073.91        363.56        366.09
# 17273          3.35          0.00          7.34          1.41          0.00
# 17274         36.53         60.82        116.78         66.18         25.54
#
#        ...  TCGA-85-7710  TCGA-56-7580  TCGA-43-6647  TCGA-90-6837  \
# 0      ...         90.77         59.55         40.07         22.92
# 1      ...        185.11        119.26        102.97        123.50
# 2      ...        813.63       2400.97        543.96       2193.99
# 3      ...         34.51         70.01         57.49         57.89
# 4      ...        251.48        209.84        120.10        109.66
# ...    ...           ...           ...           ...           ...
# 17270  ...        145.02        202.66        111.99        371.22
# 17271  ...       3955.48       4869.99       6935.54       4836.35
# 17272  ...        559.28        579.04        420.68        366.09
# 17273  ...          6.94          1.00          0.00          4.58
# 17274  ...         38.12         17.64         14.56         14.35
#
#        TCGA-56-8083  TCGA-51-4079  TCGA-56-7222  TCGA-22-4593  TCGA-51-4081  \
# 0             29.91         82.29          4.70         37.32         43.63
# 1            264.03        194.36        166.73        105.15        185.11
# 2            540.19        521.76        253.23        764.36        518.15
# 3             67.12         34.51         22.10         31.90         28.24
# 4            155.50        162.14        277.20         86.43        164.42
# ...             ...           ...           ...           ...           ...
# 17270        154.42        289.02         32.59        191.67        204.07
# 17271       7230.10       6250.56       6840.04       5292.48       3928.15
# 17272        334.46        258.57        329.84       1030.12        665.29
# 17273          0.96          3.06          1.83          1.77          3.63
# 17274          5.77         24.28         21.78         16.27         73.54
#
#        TCGA-56-8309
# 0             77.25
# 1            356.05
# 2            878.17
# 3             49.91
# 4            155.50
# ...             ...
# 17270         88.26
# 17271       7130.55
# 17272        633.73
# 17273          2.56
# 17274         88.26
#
# [17275 rows x 50 columns]

# %% [markdown]
# # 3. Calculate Fold Change Parameters

# %%
# A column to hold the Avg. value of every sample's gene expressions
df_cancer['average_GE']=df_cancer.iloc[:,3:].mean(axis=1)
df_healthy['average_GE']=df_healthy.iloc[:,3:].mean(axis=1)

df_cancer['average_GE']
# Out:
# 0          286.4534
# 1          187.4482
# 2          490.3438
# 3           14.0076
# 4          138.4650
#             ...
# 17270       80.3896
# 17271    13603.9096
# 17272      203.5698
# 17273       11.5644
# 17274      231.5940
# Name: average_GE, Length: 17275, dtype: float64

# %%
df_healthy['average_GE']
# Out:
# 0          53.6660
# 1         171.9386
# 2         866.3358
# 3          41.5340
# 4         167.0196
#            ...
# 17270     163.5038
# 17271    6091.8848
# 17272     512.2180
# 17273       1.9818
# 17274      50.2584
# Name: average_GE, Length: 17275, dtype: float64

# %%
# Creating a DataFrame to hold the Fold Change Data
FC = pd.DataFrame()

# Initialize it with the genes' names and IDs
FC['Hugo_Symbol'] = df_cancer['Hugo_Symbol']
FC['Entrez_Gene_Id'] = df_cancer['Entrez_Gene_Id']

FC
# Out:
#          Hugo_Symbol  Entrez_Gene_Id
# 0           HIST3H2A           92815
# 1              LIN7B           64130
# 2                LXN           56925
# 3             CNKSR2           22866
# 4              SCML1            6322
# ...              ...             ...
# 17270         ZNF521           25925
# 17271         SPINT2           10653
# 17272         HAVCR2           84868
# 17273  CTD-2116N17.1               0
# 17274           FUT2            2524
#
# [17275 rows x 2 columns]

# %%
# Apply the fold change equation (Gene expression level under the diseased condition/Gene expression level under the normal condition)
FC['FC']=df_cancer['average_GE']/df_healthy['average_GE']

FC
# Out:
#          Hugo_Symbol  Entrez_Gene_Id        FC
# 0           HIST3H2A           92815  5.337707
# 1              LIN7B           64130  1.090204
# 2                LXN           56925  0.565997
# 3             CNKSR2           22866  0.337256
# 4              SCML1            6322  0.829034
# ...              ...             ...       ...
# 17270         ZNF521           25925  0.491668
# 17271         SPINT2           10653  2.233120
# 17272         HAVCR2           84868  0.397428
# 17273  CTD-2116N17.1               0  5.835301
# 17274           FUT2            2524  4.608066
#
# [17275 rows x 3 columns]

# %%
# FC measures the change in units of the normal GE level
# Log-transform the FC to base 2 
FC['log2FC']=np.log2(FC['FC'])
FC
# Out:
#          Hugo_Symbol  Entrez_Gene_Id        FC    log2FC
# 0           HIST3H2A           92815  5.337707  2.416220
# 1              LIN7B           64130  1.090204  0.124599
# 2                LXN           56925  0.565997 -0.821133
# 3             CNKSR2           22866  0.337256 -1.568083
# 4              SCML1            6322  0.829034 -0.270496
# ...              ...             ...       ...       ...
# 17270         ZNF521           25925  0.491668 -1.024243
# 17271         SPINT2           10653  2.233120  1.159061
# 17272         HAVCR2           84868  0.397428 -1.331234
# 17273  CTD-2116N17.1               0  5.835301  2.544807
# 17274           FUT2            2524  4.608066  2.204161
#
# [17275 rows x 4 columns]

# %%
# Calculating the absolute value (The Change is a +ve quantitiy)
FC['ABS']=FC['log2FC'].abs()
FC
# Out:
#          Hugo_Symbol  Entrez_Gene_Id        FC    log2FC       ABS
# 0           HIST3H2A           92815  5.337707  2.416220  2.416220
# 1              LIN7B           64130  1.090204  0.124599  0.124599
# 2                LXN           56925  0.565997 -0.821133  0.821133
# 3             CNKSR2           22866  0.337256 -1.568083  1.568083
# 4              SCML1            6322  0.829034 -0.270496  0.270496
# ...              ...             ...       ...       ...       ...
# 17270         ZNF521           25925  0.491668 -1.024243  1.024243
# 17271         SPINT2           10653  2.233120  1.159061  1.159061
# 17272         HAVCR2           84868  0.397428 -1.331234  1.331234
# 17273  CTD-2116N17.1               0  5.835301  2.544807  2.544807
# 17274           FUT2            2524  4.608066  2.204161  2.204161
#
# [17275 rows x 5 columns]

# %%
# Set a threshold to apply to FC
Threshold=math.log(1.5,2)
Threshold
# Out:
# 0.5849625007211562

# %%
# Set a condition to decide significance 
# FC values less than threshold doesn't indicate significance
FC.loc[FC['ABS'] < Threshold, 'segnificant'] = 0 
# FC values >= threshold indicates significance
FC.loc[FC['ABS'] >= Threshold, 'segnificant'] = 1
FC
# Out:
#          Hugo_Symbol  Entrez_Gene_Id        FC    log2FC       ABS  \
# 0           HIST3H2A           92815  5.337707  2.416220  2.416220
# 1              LIN7B           64130  1.090204  0.124599  0.124599
# 2                LXN           56925  0.565997 -0.821133  0.821133
# 3             CNKSR2           22866  0.337256 -1.568083  1.568083
# 4              SCML1            6322  0.829034 -0.270496  0.270496
# ...              ...             ...       ...       ...       ...
# 17270         ZNF521           25925  0.491668 -1.024243  1.024243
# 17271         SPINT2           10653  2.233120  1.159061  1.159061
# 17272         HAVCR2           84868  0.397428 -1.331234  1.331234
# 17273  CTD-2116N17.1               0  5.835301  2.544807  2.544807
# 17274           FUT2            2524  4.608066  2.204161  2.204161
#
#        segnificant
# 0              1.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              0.0
# ...            ...
# 17270          1.0
# 17271          1.0
# 17272          1.0
# 17273          1.0
# 17274          1.0
#
# [17275 rows x 6 columns]

# %%
# Significant genes are expressed
FC.loc[FC['segnificant'] ==1, 'expressed'] = 'expressed' 

# Non-Significant genes are not expressed
FC.loc[FC['segnificant'] ==0 , 'expressed'] = 'not expressed' 
FC
# Out:
#          Hugo_Symbol  Entrez_Gene_Id        FC    log2FC       ABS  \
# 0           HIST3H2A           92815  5.337707  2.416220  2.416220
# 1              LIN7B           64130  1.090204  0.124599  0.124599
# 2                LXN           56925  0.565997 -0.821133  0.821133
# 3             CNKSR2           22866  0.337256 -1.568083  1.568083
# 4              SCML1            6322  0.829034 -0.270496  0.270496
# ...              ...             ...       ...       ...       ...
# 17270         ZNF521           25925  0.491668 -1.024243  1.024243
# 17271         SPINT2           10653  2.233120  1.159061  1.159061
# 17272         HAVCR2           84868  0.397428 -1.331234  1.331234
# 17273  CTD-2116N17.1               0  5.835301  2.544807  2.544807
# 17274           FUT2            2524  4.608066  2.204161  2.204161
#
#        segnificant      expressed
# 0              1.0      expressed
# 1              0.0  not expressed
# 2              1.0      expressed
# 3              1.0      expressed
# 4              0.0  not expressed
# ...            ...            ...
# 17270          1.0      expressed
# 17271          1.0      expressed
# 17272          1.0      expressed
# 17273          1.0      expressed
# 17274          1.0      expressed
#
# [17275 rows x 7 columns]

# %%
# A function to calculate expression level based on log2FC value
def f(x):  
    # While the gene is expressed: if Log2FC is positive, the gene is Over expressed
    if x['log2FC'] > 0 and x['expressed'] == 'expressed': return 'over expressed'
    # While the gene is expressed: if Log2FC is negative, the gene is Under expressed
    elif x['log2FC'] < 0 and x['expressed'] == 'expressed': return 'under expressed'
    # Otherwise the gene is still not expressed
    else: return 'not expressed'

# Apply the function on the expression column
FC['expressed'] = FC.apply(f, axis=1)
FC
# Out:
#          Hugo_Symbol  Entrez_Gene_Id        FC    log2FC       ABS  \
# 0           HIST3H2A           92815  5.337707  2.416220  2.416220
# 1              LIN7B           64130  1.090204  0.124599  0.124599
# 2                LXN           56925  0.565997 -0.821133  0.821133
# 3             CNKSR2           22866  0.337256 -1.568083  1.568083
# 4              SCML1            6322  0.829034 -0.270496  0.270496
# ...              ...             ...       ...       ...       ...
# 17270         ZNF521           25925  0.491668 -1.024243  1.024243
# 17271         SPINT2           10653  2.233120  1.159061  1.159061
# 17272         HAVCR2           84868  0.397428 -1.331234  1.331234
# 17273  CTD-2116N17.1               0  5.835301  2.544807  2.544807
# 17274           FUT2            2524  4.608066  2.204161  2.204161
#
#        segnificant        expressed
# 0              1.0   over expressed
# 1              0.0    not expressed
# 2              1.0  under expressed
# 3              1.0  under expressed
# 4              0.0    not expressed
# ...            ...              ...
# 17270          1.0  under expressed
# 17271          1.0   over expressed
# 17272          1.0  under expressed
# 17273          1.0   over expressed
# 17274          1.0   over expressed
#
# [17275 rows x 7 columns]

# %% [markdown]
# ## Plotting The Log-Transformed Fold Change Values for every gene

# %%
# Creating a color list for the FC plot
cc=['r']*len(FC['log2FC'])

for n,val in enumerate(FC['log2FC']):
    if val<0:
        # Assign Blue color for Negative values 
        cc[n]='b'
    elif val>=0:
        # Assign Red color for Positive values 
        cc[n]='r'

# %%
# Plot the Log-transformed FC for every gene
plt.figure(figsize=(20,10))
plt.bar(FC["Hugo_Symbol"],FC['log2FC'],color=cc)
plt.xlabel('genes', fontsize=16)
plt.ylabel('log2FC', fontsize=16)
plt.show()

# %% [markdown]
# # 4. Volcano Plot
# - Combining Hypothesis Test (For the paired data) and FC  to infer DEGs

# %%
# We consider the FDR-Corrected P-Values of the Wilcoxon test to plot the Volcano Plot
paired['fdr'].min()
# Out:
# 1.093136886055739e-08

# %%
# Log-Transform the fdr-corrected p-Values (Significance level) to base 10
FC['segnificance (-log10)']=-np.log10(paired['fdr'])

# %%
FC
# Out:
#          Hugo_Symbol  Entrez_Gene_Id        FC    log2FC       ABS  \
# 0           HIST3H2A           92815  5.337707  2.416220  2.416220
# 1              LIN7B           64130  1.090204  0.124599  0.124599
# 2                LXN           56925  0.565997 -0.821133  0.821133
# 3             CNKSR2           22866  0.337256 -1.568083  1.568083
# 4              SCML1            6322  0.829034 -0.270496  0.270496
# ...              ...             ...       ...       ...       ...
# 17270         ZNF521           25925  0.491668 -1.024243  1.024243
# 17271         SPINT2           10653  2.233120  1.159061  1.159061
# 17272         HAVCR2           84868  0.397428 -1.331234  1.331234
# 17273  CTD-2116N17.1               0  5.835301  2.544807  2.544807
# 17274           FUT2            2524  4.608066  2.204161  2.204161
#
#        segnificant        expressed  segnificance (-log10)
# 0              1.0   over expressed               7.329498
# 1              0.0    not expressed               0.559684
# 2              1.0  under expressed               5.367523
# 3              1.0  under expressed               7.249469
# 4              0.0    not expressed               1.653059
# ...            ...              ...                    ...
# 17270          1.0  under expressed               4.713349
# 17271          1.0   over expressed               7.582305
# 17272          1.0  under expressed               7.692487
# 17273          1.0   over expressed               7.730877
# 17274          1.0   over expressed               6.727323
#
# [17275 rows x 8 columns]

# %% [markdown]
# ## Plotting the Volcano Plot

# %%
# Creating a color list for the Volcano plot
cc=['g']*len(FC['log2FC'])
for n,val in enumerate(FC['log2FC']):
    if val<0:
        # Assign Blue color for Negative values 
        cc[n]='b'
    elif val>0:
        # Assign Red color for Positive values 
        cc[n]='r'

# %%
# Plot the volcano plot between hypothesis and FC results 
# (Scatter between FDR-Corrected Wolcoxon Significance Level and Log-Transformed FC value)
plt.figure(figsize=(10,10))
plt.scatter(FC['log2FC'], FC['segnificance (-log10)'], c =cc, alpha=0.5, s=20)
plt.xlabel('log2FC', fontsize=16)
plt.ylabel('segnificance (-log10)', fontsize=16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Considering the expression level by changing the color mapping
cc=['g']*len(FC['expressed'])
for n,val in enumerate(FC['expressed']):
    # Red if Over Expressed
    if val== 'over expressed':
        cc[n]='r'
    # Blue if Under Expressed
    elif val=='under expressed':
        cc[n]='b'
# Gray if not Expressed
for n,val in enumerate(FC['expressed']):
    if val=='not expressed':
        cc[n]='gray'

# %%
# Volcano Plot after considering Expression level
plt.figure(figsize=(10,10))
plt.scatter(FC['log2FC'], FC['segnificance (-log10)'], c =cc, alpha=0.5, s=20)
plt.xlabel('log2FC', fontsize=16)
plt.ylabel('segnificance (-log10)', fontsize=16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Considering the log-transformed significance level by changing the color mapping
cc=['g']*len(FC['log2FC'])
for n,val in enumerate(FC['log2FC']):
    # Blue for Negative log FC
    if val<0:
        cc[n]='b'
    # Red for positive log FC
    elif val>0:
        cc[n]='r'
# Gray for genes with FDR Significance less than -0.05 (But log transformed to base 10)
for n,val in enumerate(FC['segnificance (-log10)']):
    if val<-math.log(5/100,10):
        cc[n]='gray'

# %%
# Volcano Plot after considering Significance level thresholding
plt.figure(figsize=(10,10))
plt.scatter(FC['log2FC'], FC['segnificance (-log10)'], c =cc, alpha=0.5, s=20)
plt.xlabel('log2FC', fontsize=16)
plt.ylabel('segnificance (-log10)', fontsize=16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Considering the log-transformed significance level Thresholding and Expression Level colors
cc=['g']*len(FC['expressed'])
for n,val in enumerate(FC['expressed']):
    #Red if Over expressed
    if val== 'over expressed':
        cc[n]='r'
    # Blue If under Expressed
    elif val=='under expressed':
        cc[n]='b'

# Gray if not Expressed
for n,val in enumerate(FC['expressed']):
    if val=='not expressed':
        cc[n]='gray'
        
# Gray for genes with FDR Significance less than -0.05 (But log transformed to base 10
for n,val in enumerate(FC['segnificance (-log10)']):
    if val<-math.log(5/100,10):
        cc[n]='gray'

# %%
# The Volcano Plot after Considering the log-transformed significance level Thresholding and Expression Level colors
plt.figure(figsize=(10,10))
plt.scatter(FC['log2FC'], FC['segnificance (-log10)'], c =cc, alpha=0.5, s=20)
plt.xlabel('log2FC', fontsize=16)
plt.ylabel('segnificance (-log10)', fontsize=16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# FC['segnificance (-log10)']=-np.log10(paired['fdr'])
# FC.to_csv('FoldChange_fdr.csv')

# %%
# FC['segnificance (-log10)']=-np.log10(paired['p'])
# FC.to_csv('FoldChange_p.csv')
